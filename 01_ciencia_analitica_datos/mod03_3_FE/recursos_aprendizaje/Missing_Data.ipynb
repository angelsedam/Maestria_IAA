# %% [markdown]
# # Python for Data Analysis
#
#     AUTHOR: Dr. Wes McKinney
#
# ### Chapter 7: Data Cleaning and Preparation
# ### **7.1 Handling Missing Data**

# %%
import numpy as np
import pandas as pd

# %%
float_data = pd.Series([1.2, -3.5, np.nan, 0])
float_data
# Out:
# 0    1.2
# 1   -3.5
# 2    NaN
# 3    0.0
# dtype: float64

# %%
float_data.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
string_data = pd.Series(["aardvark", np.nan, None, "avocado"])
string_data
string_data.isna()
float_data = pd.Series([1, 2, None], dtype='float64')
float_data
float_data.isna()
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
data = pd.Series([1, np.nan, 3.5, np.nan, 7])
data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data[data.notna()]
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data = pd.DataFrame([[1., 6.5, 3.], [1., np.nan, np.nan],
                     [np.nan, np.nan, np.nan], [np.nan, 6.5, 3.]])
data
data.dropna()
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
data.dropna(how="all")
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data[4] = np.nan
data
data.dropna(axis="columns", how="all")
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
df = pd.DataFrame(np.random.standard_normal((7, 3)))
df.iloc[:4, 1] = np.nan
df.iloc[:2, 2] = np.nan
df
df.dropna()
df.dropna(thresh=2)
# Out:
#           0         1         2
# 2 -0.757195       NaN  0.105805
# 3 -0.038377       NaN -0.512539
# 4  1.549233 -0.763423 -0.722001
# 5  0.566104  0.988847 -0.316637
# 6 -0.324285  0.579226 -0.595578

# %%
df.fillna(0)
# Out:
#           0         1         2
# 0 -0.663941  0.000000  0.000000
# 1 -1.229059  0.000000  0.000000
# 2 -0.757195  0.000000  0.105805
# 3 -0.038377  0.000000 -0.512539
# 4  1.549233 -0.763423 -0.722001
# 5  0.566104  0.988847 -0.316637
# 6 -0.324285  0.579226 -0.595578

# %%
df.fillna({1: 0.5, 2: 0})
# Out:
#           0         1         2
# 0 -0.663941  0.500000  0.000000
# 1 -1.229059  0.500000  0.000000
# 2 -0.757195  0.500000  0.105805
# 3 -0.038377  0.500000 -0.512539
# 4  1.549233 -0.763423 -0.722001
# 5  0.566104  0.988847 -0.316637
# 6 -0.324285  0.579226 -0.595578

# %%
df = pd.DataFrame(np.random.standard_normal((6, 3)))
df.iloc[2:, 1] = np.nan
df.iloc[4:, 2] = np.nan
df
df.fillna(method="ffill")
df.fillna(method="ffill", limit=2)
# Out:
#           0         1         2
# 0 -0.632270 -2.284591 -1.762035
# 1  1.040455 -0.021868 -1.266315
# 2  0.340235 -0.021868  0.160739
# 3  0.911027 -0.021868 -0.190067
# 4 -0.265947       NaN -0.190067
# 5 -1.750046       NaN -0.190067

# %%
data = pd.Series([1., np.nan, 3.5, np.nan, 7])
data.fillna(data.mean())
# Out:
# 0    1.000000
# 1    3.833333
# 2    3.500000
# 3    3.833333
# 4    7.000000
# dtype: float64

# %% [markdown]
# # Removing Duplicates

# %%
data = pd.DataFrame({"k1": ["one", "two"] * 3 + ["two"],
                     "k2": [1, 1, 2, 3, 3, 4, 4]})
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %%
data["v1"] = range(7)
data
data.drop_duplicates(subset=["k1"])
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1

# %%
data.drop_duplicates(["k1", "k2"], keep="last")
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   3   4
# 6  two   4   6
