# %% [markdown]
# **MAESTRÍA EN INTELIGENCIA ARTIFICIAL APLICADA**
#
# **Curso: TC4029 - Ciencia y analítica de datos**
#
# Tecnológico de Monterrey
#
# Prof Grettel Barceló Alonso
#
# **Semana 5**
# Preprocesamiento de datos
#
# ---

# %% [markdown]
# *   NOMBRE: ---------------------------------------------------------
# *   MATRÍCULA: ----------------------------------------------------

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#import os
#DIR = "/content/drive/MyDrive/Colab Notebooks/MNA/TC4029 - Ciencia y analítica de datos/Semana 5/Actividad5_Preprocesamiento"
#os.chdir(DIR)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('responses.csv')
df
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0       5.0                       3.0    2.0   1.0      2.0              2.0
# 1       4.0                       4.0    2.0   1.0      1.0              1.0
# 2       5.0                       5.0    2.0   2.0      3.0              4.0
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 4       5.0                       3.0    4.0   3.0      2.0              4.0
# ...     ...                       ...    ...   ...      ...              ...
# 1005    5.0                       2.0    5.0   2.0      2.0              5.0
# 1006    4.0                       4.0    5.0   1.0      3.0              4.0
# 1007    4.0                       3.0    1.0   1.0      2.0              2.0
# 1008    5.0                       3.0    3.0   3.0      1.0              3.0
# 1009    5.0                       5.0    4.0   3.0      2.0              3.0
#
#       Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# 0         1.0  5.0   5.0                1.0  ...  20.0   163.0    48.0
# 1         2.0  3.0   5.0                4.0  ...  19.0   163.0    58.0
# 2         5.0  3.0   5.0                3.0  ...  20.0   176.0    67.0
# 3         1.0  2.0   2.0                1.0  ...  22.0   172.0    59.0
# 4         3.0  5.0   3.0                1.0  ...  20.0   170.0    59.0
# ...       ...  ...   ...                ...  ...   ...     ...     ...
# 1005      4.0  4.0   4.0                3.0  ...  20.0   164.0    57.0
# 1006      1.0  4.0   1.0                1.0  ...  27.0   183.0    80.0
# 1007      2.0  3.0   4.0                1.0  ...  18.0   173.0    75.0
# 1008      1.0  3.0   4.0                1.0  ...  25.0   173.0    58.0
# 1009      3.0  4.0   1.0                1.0  ...  21.0   185.0    72.0
#
#       Number of siblings  Gender  Left - right handed  \
# 0                    1.0  female         right handed
# 1                    2.0  female         right handed
# 2                    2.0  female         right handed
# 3                    1.0  female         right handed
# 4                    1.0  female         right handed
# ...                  ...     ...                  ...
# 1005                 1.0  female         right handed
# 1006                 5.0    male          left handed
# 1007                 0.0  female         right handed
# 1008                 1.0  female         right handed
# 1009                 1.0    male         right handed
#
#                     Education  Only child  Village - town  \
# 0     college/bachelor degree          no         village
# 1     college/bachelor degree          no            city
# 2            secondary school          no            city
# 3     college/bachelor degree         yes            city
# 4            secondary school          no         village
# ...                       ...         ...             ...
# 1005         secondary school          no            city
# 1006           masters degree          no         village
# 1007         secondary school         yes            city
# 1008  college/bachelor degree          no            city
# 1009         secondary school          no         village
#
#       House - block of flats
# 0             block of flats
# 1             block of flats
# 2             block of flats
# 3             house/bungalow
# 4             house/bungalow
# ...                      ...
# 1005          house/bungalow
# 1006          house/bungalow
# 1007          block of flats
# 1008          block of flats
# 1009          house/bungalow
#
# [1010 rows x 150 columns]

# %% [markdown]
# 1. Determina cuántas variables numéricas y cuántas de texto posee el conjunto de datos con el método `info()` y utiliza el método `describe()` del dataframe, para obtener el resumen de las estadísticas descriptivas. Separa el análisis según el tipo de datos (number, object).

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Data columns (total 150 columns):
#  #    Column                          Non-Null Count  Dtype
# ---   ------                          --------------  -----
#  0    Music                           1007 non-null   float64
#  1    Slow songs or fast songs        1008 non-null   float64
#  2    Dance                           1006 non-null   float64
#  3    Folk                            1005 non-null   float64
#  4    Country                         1005 non-null   float64
#  5    Classical music                 1003 non-null   float64
#  6    Musical                         1008 non-null   float64
#  7    Pop                             1007 non-null   float64
#  8    Rock                            1004 non-null   float64
#  9    Metal or Hardrock               1007 non-null   float64
#  10   Punk                            1002 non-null   float64
#  11   Hiphop, Rap                     1006 non-null   float64
#  12   Reggae, Ska                     1003 non-null   float64
#  13   Swing, Jazz                     1004 non-null   float64
#  14   Rock n roll                     1003 non-null   float64
#  15   Alternative                     1003 non-null   float64
#  16   Latino                          1002 non-null   float64
#  17   Techno, Trance                  1003 non-null   float64
#  18   Opera                           1009 non-null   float64
#  19   Movies                          1004 non-null   float64
#  20   Horror                          1008 non-null   float64
#  21   Thriller                        1009 non-null   float64
#  22   Comedy                          1007 non-null   float64
#  23   Romantic                        1007 non-null   float64
#  24   Sci-fi                          1008 non-null   float64
#  25   War                             1008 non-null   float64
#  26   Fantasy/Fairy tales             1007 non-null   float64
#  27   Animated                        1007 non-null   float64
#  28   Documentary                     1002 non-null   float64
#  29   Western                         1006 non-null   float64
#  30   Action                          1008 non-null   float64
#  31   History                         1008 non-null   float64
#  32   Psychology                      1005 non-null   float64
#  33   Politics                        1009 non-null   float64
#  34   Mathematics                     1007 non-null   float64
#  35   Physics                         1007 non-null   float64
#  36   Internet                        1006 non-null   float64
#  37   PC                              1004 non-null   float64
#  38   Economy Management              1005 non-null   float64
#  39   Biology                         1004 non-null   float64
#  40   Chemistry                       1000 non-null   float64
#  41   Reading                         1004 non-null   float64
#  42   Geography                       1001 non-null   float64
#  43   Foreign languages               1005 non-null   float64
#  44   Medicine                        1005 non-null   float64
#  45   Law                             1009 non-null   float64
#  46   Cars                            1006 non-null   float64
#  47   Art exhibitions                 1004 non-null   float64
#  48   Religion                        1007 non-null   float64
#  49   Countryside, outdoors           1003 non-null   float64
#  50   Dancing                         1007 non-null   float64
#  51   Musical instruments             1009 non-null   float64
#  52   Writing                         1004 non-null   float64
#  53   Passive sport                   995 non-null    float64
#  54   Active sport                    1006 non-null   float64
#  55   Gardening                       1003 non-null   float64
#  56   Celebrities                     1008 non-null   float64
#  57   Shopping                        1008 non-null   float64
#  58   Science and technology          1004 non-null   float64
#  59   Theatre                         1002 non-null   float64
#  60   Fun with friends                1006 non-null   float64
#  61   Adrenaline sports               1007 non-null   float64
#  62   Pets                            1006 non-null   float64
#  63   Flying                          1007 non-null   float64
#  64   Storm                           1009 non-null   float64
#  65   Darkness                        1008 non-null   float64
#  66   Heights                         1007 non-null   float64
#  67   Spiders                         1005 non-null   float64
#  68   Snakes                          1010 non-null   int64
#  69   Rats                            1007 non-null   float64
#  70   Ageing                          1009 non-null   float64
#  71   Dangerous dogs                  1009 non-null   float64
#  72   Fear of public speaking         1009 non-null   float64
#  73   Smoking                         1002 non-null   object
#  74   Alcohol                         1005 non-null   object
#  75   Healthy eating                  1007 non-null   float64
#  76   Daily events                    1003 non-null   float64
#  77   Prioritising workload           1005 non-null   float64
#  78   Writing notes                   1007 non-null   float64
#  79   Workaholism                     1005 non-null   float64
#  80   Thinking ahead                  1007 non-null   float64
#  81   Final judgement                 1003 non-null   float64
#  82   Reliability                     1006 non-null   float64
#  83   Keeping promises                1009 non-null   float64
#  84   Loss of interest                1006 non-null   float64
#  85   Friends versus money            1004 non-null   float64
#  86   Funniness                       1006 non-null   float64
#  87   Fake                            1009 non-null   float64
#  88   Criminal damage                 1003 non-null   float64
#  89   Decision making                 1006 non-null   float64
#  90   Elections                       1007 non-null   float64
#  91   Self-criticism                  1005 non-null   float64
#  92   Judgment calls                  1006 non-null   float64
#  93   Hypochondria                    1006 non-null   float64
#  94   Empathy                         1005 non-null   float64
#  95   Eating to survive               1010 non-null   int64
#  96   Giving                          1004 non-null   float64
#  97   Compassion to animals           1003 non-null   float64
#  98   Borrowed stuff                  1008 non-null   float64
#  99   Loneliness                      1009 non-null   float64
#  100  Cheating in school              1006 non-null   float64
#  101  Health                          1009 non-null   float64
#  102  Changing the past               1008 non-null   float64
#  103  God                             1008 non-null   float64
#  104  Dreams                          1010 non-null   int64
#  105  Charity                         1007 non-null   float64
#  106  Number of friends               1010 non-null   int64
#  107  Punctuality                     1008 non-null   object
#  108  Lying                           1008 non-null   object
#  109  Waiting                         1007 non-null   float64
#  110  New environment                 1008 non-null   float64
#  111  Mood swings                     1006 non-null   float64
#  112  Appearence and gestures         1007 non-null   float64
#  113  Socializing                     1005 non-null   float64
#  114  Achievements                    1008 non-null   float64
#  115  Responding to a serious letter  1004 non-null   float64
#  116  Children                        1006 non-null   float64
#  117  Assertiveness                   1008 non-null   float64
#  118  Getting angry                   1006 non-null   float64
#  119  Knowing the right people        1008 non-null   float64
#  120  Public speaking                 1008 non-null   float64
#  121  Unpopularity                    1007 non-null   float64
#  122  Life struggles                  1007 non-null   float64
#  123  Happiness in life               1006 non-null   float64
#  124  Energy levels                   1005 non-null   float64
#  125  Small - big dogs                1006 non-null   float64
#  126  Personality                     1006 non-null   float64
#  127  Finding lost valuables          1006 non-null   float64
#  128  Getting up                      1005 non-null   float64
#  129  Interests or hobbies            1007 non-null   float64
#  130  Parents' advice                 1008 non-null   float64
#  131  Questionnaires or polls         1006 non-null   float64
#  132  Internet usage                  1010 non-null   object
#  133  Finances                        1007 non-null   float64
#  134  Shopping centres                1008 non-null   float64
#  135  Branded clothing                1008 non-null   float64
#  136  Entertainment spending          1007 non-null   float64
#  137  Spending on looks               1007 non-null   float64
#  138  Spending on gadgets             1010 non-null   int64
#  139  Spending on healthy eating      1008 non-null   float64
#  140  Age                             1003 non-null   float64
#  141  Height                          990 non-null    float64
#  142  Weight                          990 non-null    float64
#  143  Number of siblings              1004 non-null   float64
#  144  Gender                          1004 non-null   object
#  145  Left - right handed             1007 non-null   object
#  146  Education                       1009 non-null   object
#  147  Only child                      1008 non-null   object
#  148  Village - town                  1006 non-null   object
#  149  House - block of flats          1006 non-null   object
# dtypes: float64(134), int64(5), object(11)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#              Music  Slow songs or fast songs        Dance         Folk  \
# count  1007.000000               1008.000000  1006.000000  1005.000000
# mean      4.731877                  3.328373     3.113320     2.288557
# std       0.664049                  0.833931     1.170568     1.138916
# min       1.000000                  1.000000     1.000000     1.000000
# 25%       5.000000                  3.000000     2.000000     1.000000
# 50%       5.000000                  3.000000     3.000000     2.000000
# 75%       5.000000                  4.000000     4.000000     3.000000
# max       5.000000                  5.000000     5.000000     5.000000
#
#            Country  Classical music      Musical          Pop         Rock  \
# count  1005.000000      1003.000000  1008.000000  1007.000000  1004.000000
# mean      2.123383         2.956132     2.761905     3.471698     3.761952
# std       1.076136         1.252570     1.260845     1.161400     1.184861
# min       1.000000         1.000000     1.000000     1.000000     1.000000
# 25%       1.000000         2.000000     2.000000     3.000000     3.000000
# 50%       2.000000         3.000000     3.000000     4.000000     4.000000
# 75%       3.000000         4.000000     4.000000     4.000000     5.000000
# max       5.000000         5.000000     5.000000     5.000000     5.000000
#
#        Metal or Hardrock  ...  Shopping centres  Branded clothing  \
# count        1007.000000  ...       1008.000000       1008.000000
# mean            2.361470  ...          3.234127          3.050595
# std             1.372995  ...          1.323062          1.306321
# min             1.000000  ...          1.000000          1.000000
# 25%             1.000000  ...          2.000000          2.000000
# 50%             2.000000  ...          3.000000          3.000000
# 75%             3.000000  ...          4.000000          4.000000
# max             5.000000  ...          5.000000          5.000000
#
#        Entertainment spending  Spending on looks  Spending on gadgets  \
# count             1007.000000        1007.000000          1010.000000
# mean                 3.201589           3.106256             2.870297
# std                  1.188947           1.205368             1.284970
# min                  1.000000           1.000000             1.000000
# 25%                  2.000000           2.000000             2.000000
# 50%                  3.000000           3.000000             3.000000
# 75%                  4.000000           4.000000             4.000000
# max                  5.000000           5.000000             5.000000
#
#        Spending on healthy eating          Age      Height      Weight  \
# count                  1008.00000  1003.000000  990.000000  990.000000
# mean                      3.55754    20.433699  173.514141   66.405051
# std                       1.09375     2.828840   10.024505   13.839561
# min                       1.00000    15.000000   62.000000   41.000000
# 25%                       3.00000    19.000000  167.000000   55.000000
# 50%                       4.00000    20.000000  173.000000   64.000000
# 75%                       4.00000    22.000000  180.000000   75.000000
# max                       5.00000    30.000000  203.000000  165.000000
#
#        Number of siblings
# count         1004.000000
# mean             1.297809
# std              1.013348
# min              0.000000
# 25%              1.000000
# 50%              1.000000
# 75%              2.000000
# max             10.000000
#
# [8 rows x 139 columns]

# %% [markdown]
# 2. Clasifique la variable `Weight` según su escala de medición. En función de ello elija el gráfico a generar (histograma / barras) y fundamente su elección.

# %%
df['Weight'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# 3. Clasifique la distribución del peso según su asimetría, justificando tu respuesta. Incluye el cálculo numérico que lo demuestra.

# %%
df['Weight'].describe()
# Out:
# count    990.000000
# mean      66.405051
# std       13.839561
# min       41.000000
# 25%       55.000000
# 50%       64.000000
# 75%       75.000000
# max      165.000000
# Name: Weight, dtype: float64

# %%
df.loc[:,"Weight"].skew()
# Out:
# 1.2237251927527477

# %% [markdown]
# Asimetria positiva

# %% [markdown]
# 4. ¿Cuántos valores faltantes tiene la variable `Weight`? ¿Qué porcentaje representa?

# %%
df['Weight'].isna().sum()
# Out:
# 20

# %%
df['Weight'].isna().sum()/df['Weight'].sum()
# Out:
# 0.0003042241523554555

# %% [markdown]
# 5. ¿Tendrán los valores faltantes de `Weight` relación con alguna otra variable? Analízalo considerando las siguientes columnas:
# *   Numéricas: `Age, Number of siblings`
# *   Categóricas: `Gender, Education`
#
# Para ello deberás dividir cada columna en dos grupos: con/sin faltantes en `Weight` y utilizar métodos gráficos y la prueba t para ver si hay diferencias significativas.
#
# **NOTA**. Puedes reutilizar las funciones `Diagnose_MV_Numerical` y `Diagnose_MV_Categorical` definidas en Hands-On-Prep_Missing_Values.zip. Revisa nuevamente cómo utilizarlas.

# %%
from scipy.stats import ttest_ind
def Diagnose_MV_Numerical(df,str_att_name,BM_MV):
    MV_labels = {True:'With Missing Values',False:'Without Missing Values'}

    labels=[]
    box_sr = pd.Series('',index = BM_MV.unique())
    for poss in BM_MV.unique():
        BM = BM_MV == poss
        box_sr[poss] = df[BM][str_att_name].dropna()
        labels.append(MV_labels[poss])

    plt.boxplot(box_sr,vert=False)
    plt.yticks([1,2],labels)
    plt.xlabel(str_att_name)
    plt.show()

    plt.figure(figsize=(10,4))

    att_range = (df[str_att_name].min(),df[str_att_name].max())

    for i,poss in enumerate(BM_MV.unique()):
        plt.subplot(1,2,i+1)
        BM = BM_MV == poss
        df[BM][str_att_name].hist()
        plt.xlim = att_range
        plt.xlabel(str_att_name)
        plt.title(MV_labels[poss])

    plt.show()

    group_1_data = df[BM_MV][str_att_name].dropna()
    group_2_data = df[~BM_MV][str_att_name].dropna()

    p_value = ttest_ind(group_1_data,group_2_data).pvalue

    print('p-value of t-test: {}'.format(p_value))

# %%
from scipy.stats import chi2_contingency
def Diagnose_MV_Categorical(df,str_att_name,BM_MV):
    MV_labels = {True:'With Missing Values',False:'Without Missing Values'}

    plt.figure(figsize=(10,4))
    for i,poss in enumerate(BM_MV.unique()):
        plt.subplot(1,2,i+1)
        BM = BM_MV == poss
        df[BM][str_att_name].value_counts().plot.bar()
        plt.title(MV_labels[poss])
    plt.show()

    contigency_table = pd.crosstab(BM_MV,df[str_att_name])
    p_value = chi2_contingency(contigency_table)[1]

    print('p-value of Chi_squared test: {}'.format(p_value))

# %%
numerical_attributes = ['Age', 'Number of siblings']
BM_MV = df.Weight.isnull()


for att in numerical_attributes:
    print('Diagnosis Analysis of Missing Values for {}:'.format(att))
    Diagnose_MV_Numerical(df,att,BM_MV)
    print('- - - - - - - - - - - - divider - - - - - - - - - - - ')
# Out:
# Diagnosis Analysis of Missing Values for Age:
# p-value of t-test: 0.7258243979822129
# - - - - - - - - - - - - divider - - - - - - - - - - -
# Diagnosis Analysis of Missing Values for Number of siblings:
# p-value of t-test: 0.8255092107556896
# - - - - - - - - - - - - divider - - - - - - - - - - -

# %%
categorical_attributes = ['Gender', 'Education']
BM_MV = df.Weight.isnull()


for att in categorical_attributes:
    print('Diagnosis Analysis of Missing Values for {}:'.format(att))
    Diagnose_MV_Categorical(df,att,BM_MV)
    print('- - - - - - - - - - - - divider - - - - - - - - - - - ')
# Out:
# Diagnosis Analysis of Missing Values for Gender:
# p-value of Chi_squared test: 0.5472167199163878
# - - - - - - - - - - - - divider - - - - - - - - - - -
# Diagnosis Analysis of Missing Values for Education:
# p-value of Chi_squared test: 0.8424822989541867
# - - - - - - - - - - - - divider - - - - - - - - - - -

# %% [markdown]
# 6. Utiliza una medida de tendencia central para imputar los valores faltantes de `Weight`. ¿Cuál es recomendable y por qué?

# %% [markdown]
# Yo utilizaria la media ya que me podria usar el promedio del peso de la poblacion, pero podria verse afectado por valores atipicos, asi que primero verificaria si hay outliers si hay utilizaria la mediana ya que esta no se ve afectada por valores atipicos

# %%
df['Weight'].fillna(df.Weight.mean())
# Out:
# 0       48.0
# 1       58.0
# 2       67.0
# 3       59.0
# 4       59.0
#         ...
# 1005    57.0
# 1006    80.0
# 1007    75.0
# 1008    58.0
# 1009    72.0
# Name: Weight, Length: 1010, dtype: float64

# %% [markdown]
# 7. ¿Hay valores atípicos de la variable `Weight`? Confírmalo con un gráfico de boxplot. ¿Cuántos son? Almacénalos en un dataframe independiente y elimínalos del conjunto original.

# %%
df.boxplot(['Weight'])
# Out:
# <AxesSubplot:>

# %%
# Calcular el IQR (rango intercuartil) de la columna de estatura
Q1 = df['Weight'].quantile(0.25)
Q3 = df['Weight'].quantile(0.75)
IQR = Q3 - Q1

# Definir los límites para identificar outliers
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# Encontrar y almacenar los outliers en un DataFrame aparte
outliers = df[(df['Weight'] < limite_inferior) | (df['Weight'] > limite_superior)]

# Eliminar los outliers del DataFrame original
df_sin_outliers = df[(df['Weight'] >= limite_inferior) & (df['Weight'] <= limite_superior)]

# Mostrar la cantidad de outliers y el DataFrame independiente
df_sin_outliers
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0       5.0                       3.0    2.0   1.0      2.0              2.0
# 1       4.0                       4.0    2.0   1.0      1.0              1.0
# 2       5.0                       5.0    2.0   2.0      3.0              4.0
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 4       5.0                       3.0    4.0   3.0      2.0              4.0
# ...     ...                       ...    ...   ...      ...              ...
# 1005    5.0                       2.0    5.0   2.0      2.0              5.0
# 1006    4.0                       4.0    5.0   1.0      3.0              4.0
# 1007    4.0                       3.0    1.0   1.0      2.0              2.0
# 1008    5.0                       3.0    3.0   3.0      1.0              3.0
# 1009    5.0                       5.0    4.0   3.0      2.0              3.0
#
#       Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# 0         1.0  5.0   5.0                1.0  ...  20.0   163.0    48.0
# 1         2.0  3.0   5.0                4.0  ...  19.0   163.0    58.0
# 2         5.0  3.0   5.0                3.0  ...  20.0   176.0    67.0
# 3         1.0  2.0   2.0                1.0  ...  22.0   172.0    59.0
# 4         3.0  5.0   3.0                1.0  ...  20.0   170.0    59.0
# ...       ...  ...   ...                ...  ...   ...     ...     ...
# 1005      4.0  4.0   4.0                3.0  ...  20.0   164.0    57.0
# 1006      1.0  4.0   1.0                1.0  ...  27.0   183.0    80.0
# 1007      2.0  3.0   4.0                1.0  ...  18.0   173.0    75.0
# 1008      1.0  3.0   4.0                1.0  ...  25.0   173.0    58.0
# 1009      3.0  4.0   1.0                1.0  ...  21.0   185.0    72.0
#
#       Number of siblings  Gender  Left - right handed  \
# 0                    1.0  female         right handed
# 1                    2.0  female         right handed
# 2                    2.0  female         right handed
# 3                    1.0  female         right handed
# 4                    1.0  female         right handed
# ...                  ...     ...                  ...
# 1005                 1.0  female         right handed
# 1006                 5.0    male          left handed
# 1007                 0.0  female         right handed
# 1008                 1.0  female         right handed
# 1009                 1.0    male         right handed
#
#                     Education  Only child  Village - town  \
# 0     college/bachelor degree          no         village
# 1     college/bachelor degree          no            city
# 2            secondary school          no            city
# 3     college/bachelor degree         yes            city
# 4            secondary school          no         village
# ...                       ...         ...             ...
# 1005         secondary school          no            city
# 1006           masters degree          no         village
# 1007         secondary school         yes            city
# 1008  college/bachelor degree          no            city
# 1009         secondary school          no         village
#
#       House - block of flats
# 0             block of flats
# 1             block of flats
# 2             block of flats
# 3             house/bungalow
# 4             house/bungalow
# ...                      ...
# 1005          house/bungalow
# 1006          house/bungalow
# 1007          block of flats
# 1008          block of flats
# 1009          house/bungalow
#
# [981 rows x 150 columns]

# %% [markdown]
# 8. Repite el mismo proceso de valores atípicos con la variable `Height`.

# %%
df.boxplot(['Height'])
# Out:
# <AxesSubplot:>

# %%
# Calcular el IQR (rango intercuartil) de la columna de estatura
Q1 = df['Height'].quantile(0.25)
Q3 = df['Height'].quantile(0.75)
IQR = Q3 - Q1

# Definir los límites para identificar outliers
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# Encontrar y almacenar los outliers en un DataFrame aparte
outliers = df[(df['Height'] < limite_inferior) | (df['Height'] > limite_superior)]

# Eliminar los outliers del DataFrame original
df_sin_outliers = df[(df['Height'] >= limite_inferior) & (df['Height'] <= limite_superior)]

# Mostrar la cantidad de outliers y el DataFrame independiente
df_sin_outliers
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0       5.0                       3.0    2.0   1.0      2.0              2.0
# 1       4.0                       4.0    2.0   1.0      1.0              1.0
# 2       5.0                       5.0    2.0   2.0      3.0              4.0
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 4       5.0                       3.0    4.0   3.0      2.0              4.0
# ...     ...                       ...    ...   ...      ...              ...
# 1005    5.0                       2.0    5.0   2.0      2.0              5.0
# 1006    4.0                       4.0    5.0   1.0      3.0              4.0
# 1007    4.0                       3.0    1.0   1.0      2.0              2.0
# 1008    5.0                       3.0    3.0   3.0      1.0              3.0
# 1009    5.0                       5.0    4.0   3.0      2.0              3.0
#
#       Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# 0         1.0  5.0   5.0                1.0  ...  20.0   163.0    48.0
# 1         2.0  3.0   5.0                4.0  ...  19.0   163.0    58.0
# 2         5.0  3.0   5.0                3.0  ...  20.0   176.0    67.0
# 3         1.0  2.0   2.0                1.0  ...  22.0   172.0    59.0
# 4         3.0  5.0   3.0                1.0  ...  20.0   170.0    59.0
# ...       ...  ...   ...                ...  ...   ...     ...     ...
# 1005      4.0  4.0   4.0                3.0  ...  20.0   164.0    57.0
# 1006      1.0  4.0   1.0                1.0  ...  27.0   183.0    80.0
# 1007      2.0  3.0   4.0                1.0  ...  18.0   173.0    75.0
# 1008      1.0  3.0   4.0                1.0  ...  25.0   173.0    58.0
# 1009      3.0  4.0   1.0                1.0  ...  21.0   185.0    72.0
#
#       Number of siblings  Gender  Left - right handed  \
# 0                    1.0  female         right handed
# 1                    2.0  female         right handed
# 2                    2.0  female         right handed
# 3                    1.0  female         right handed
# 4                    1.0  female         right handed
# ...                  ...     ...                  ...
# 1005                 1.0  female         right handed
# 1006                 5.0    male          left handed
# 1007                 0.0  female         right handed
# 1008                 1.0  female         right handed
# 1009                 1.0    male         right handed
#
#                     Education  Only child  Village - town  \
# 0     college/bachelor degree          no         village
# 1     college/bachelor degree          no            city
# 2            secondary school          no            city
# 3     college/bachelor degree         yes            city
# 4            secondary school          no         village
# ...                       ...         ...             ...
# 1005         secondary school          no            city
# 1006           masters degree          no         village
# 1007         secondary school         yes            city
# 1008  college/bachelor degree          no            city
# 1009         secondary school          no         village
#
#       House - block of flats
# 0             block of flats
# 1             block of flats
# 2             block of flats
# 3             house/bungalow
# 4             house/bungalow
# ...                      ...
# 1005          house/bungalow
# 1006          house/bungalow
# 1007          block of flats
# 1008          block of flats
# 1009          house/bungalow
#
# [984 rows x 150 columns]

# %% [markdown]
# 9. ¿Hay encuestados que sean atípicos según su índice de masa corporal (`BMI`)? El `BMI` puede ser calculado usando la siguiente fórmula:
#
# `BMI = Weight / Height ^ 2`
#
# **NOTA**. El peso tiene que estar en kilogramos y la altura en metros, pero en el conjunto la altura se ha registrado en centímetros, por lo que deberás convertirla a metros.

# %%
df['Height_in_m'] = df['Height']/100
df['Height_in_m']
# Out:
# 0       1.63
# 1       1.63
# 2       1.76
# 3       1.72
# 4       1.70
#         ...
# 1005    1.64
# 1006    1.83
# 1007    1.73
# 1008    1.73
# 1009    1.85
# Name: Height_in_m, Length: 1010, dtype: float64

# %%
df['BMI'] = df['Weight']/ pow(df['Height'],2)
df['BMI']
# Out:
# 0       0.001807
# 1       0.002183
# 2       0.002163
# 3       0.001994
# 4       0.002042
#           ...
# 1005    0.002119
# 1006    0.002389
# 1007    0.002506
# 1008    0.001938
# 1009    0.002104
# Name: BMI, Length: 1010, dtype: float64

# %%
df.boxplot(['BMI'])
# Out:
# <AxesSubplot:>

# %%
# Calcular el IQR (rango intercuartil) de la columna de estatura
Q1 = df['BMI'].quantile(0.25)
Q3 = df['BMI'].quantile(0.75)
IQR = Q3 - Q1

# Definir los límites para identificar outliers
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# Encontrar y almacenar los outliers en un DataFrame aparte
outliers = df[(df['BMI'] < limite_inferior) | (df['BMI'] > limite_superior)]

# Eliminar los outliers del DataFrame original
df_sin_outliers = df[(df['BMI'] >= limite_inferior) & (df['BMI'] <= limite_superior)]

# Mostrar la cantidad de outliers y el DataFrame independiente
df_sin_outliers
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0       5.0                       3.0    2.0   1.0      2.0              2.0
# 1       4.0                       4.0    2.0   1.0      1.0              1.0
# 2       5.0                       5.0    2.0   2.0      3.0              4.0
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 4       5.0                       3.0    4.0   3.0      2.0              4.0
# ...     ...                       ...    ...   ...      ...              ...
# 1005    5.0                       2.0    5.0   2.0      2.0              5.0
# 1006    4.0                       4.0    5.0   1.0      3.0              4.0
# 1007    4.0                       3.0    1.0   1.0      2.0              2.0
# 1008    5.0                       3.0    3.0   3.0      1.0              3.0
# 1009    5.0                       5.0    4.0   3.0      2.0              3.0
#
#       Musical  Pop  Rock  Metal or Hardrock  ...  Weight  Number of siblings  \
# 0         1.0  5.0   5.0                1.0  ...    48.0                 1.0
# 1         2.0  3.0   5.0                4.0  ...    58.0                 2.0
# 2         5.0  3.0   5.0                3.0  ...    67.0                 2.0
# 3         1.0  2.0   2.0                1.0  ...    59.0                 1.0
# 4         3.0  5.0   3.0                1.0  ...    59.0                 1.0
# ...       ...  ...   ...                ...  ...     ...                 ...
# 1005      4.0  4.0   4.0                3.0  ...    57.0                 1.0
# 1006      1.0  4.0   1.0                1.0  ...    80.0                 5.0
# 1007      2.0  3.0   4.0                1.0  ...    75.0                 0.0
# 1008      1.0  3.0   4.0                1.0  ...    58.0                 1.0
# 1009      3.0  4.0   1.0                1.0  ...    72.0                 1.0
#
#       Gender  Left - right handed                Education  Only child  \
# 0     female         right handed  college/bachelor degree          no
# 1     female         right handed  college/bachelor degree          no
# 2     female         right handed         secondary school          no
# 3     female         right handed  college/bachelor degree         yes
# 4     female         right handed         secondary school          no
# ...      ...                  ...                      ...         ...
# 1005  female         right handed         secondary school          no
# 1006    male          left handed           masters degree          no
# 1007  female         right handed         secondary school         yes
# 1008  female         right handed  college/bachelor degree          no
# 1009    male         right handed         secondary school          no
#
#       Village - town  House - block of flats  Height_in_m       BMI
# 0            village          block of flats         1.63  0.001807
# 1               city          block of flats         1.63  0.002183
# 2               city          block of flats         1.76  0.002163
# 3               city          house/bungalow         1.72  0.001994
# 4            village          house/bungalow         1.70  0.002042
# ...              ...                     ...          ...       ...
# 1005            city          house/bungalow         1.64  0.002119
# 1006         village          house/bungalow         1.83  0.002389
# 1007            city          block of flats         1.73  0.002506
# 1008            city          block of flats         1.73  0.001938
# 1009         village          house/bungalow         1.85  0.002104
#
# [965 rows x 152 columns]

# %% [markdown]
# 10. Utiliza boxplots para visualizar la distribución del `BMI` según cada una de las variables categóricas de texto. Comenta un hallazgo que llame tu atención.

# %%
columnas_object = df.select_dtypes(include=['object'])
columnas_object.columns
# Out:
# Index(['Smoking', 'Alcohol', 'Punctuality', 'Lying', 'Internet usage',
#        'Gender', 'Left - right handed', 'Education', 'Only child',
#        'Village - town', 'House - block of flats'],
#       dtype='object')

# %%
for col in columnas_object.columns:
    df.boxplot(column='BMI', by=col, vert=False)
    plt.xlabel('BMI')
    plt.title('Boxplots de BMI por ' + col )
    plt.show()
